# %% [markdown]
# ### Match location informations and POI informations

# %%
from pprint import pprint
import re
import json

# %%
with open("taiwan_districts.json", 'r') as file, open("taiwan_districts_mapping.json", 'w', encoding='utf-8-sig') as outfile:
    data = json.load(file)
    dataset = {}
    for county in data:
        districts = {}
        for d in county['districts']:
            districts[d['name']] = [d['name']]
            if len(d['name']) > 2:
                districts[d['name']].append(d['name'][:2])
        dataset[county['name']] = districts
    json.dump(dataset, outfile, ensure_ascii=False)

# %%
def countyMapping(mapping_list, addr):
    for county in mapping_list:
        match = re.search(county, addr)
        if match: return 1, county
    for county in mapping_list:
        match = re.search(county[:2], addr)
        if match: return 1, county
    #if addr has no county
    for county in mapping_list:
        pattern = "|".join(t for town in mapping_list[county] for t in mapping_list[county][town] if len(t)>2)
        if pattern == '': continue
        match = re.search(pattern, addr)
        if match: return 0, county
    return None, None

def townMapping(mapping_list, addr, countyflag):
    #if addr has no county
    if countyflag:
        addr = addr[2:]
    for key, value in mapping_list.items():
        pattern = "|".join(loc for loc in value)
        match = re.search(pattern, addr)
        if match: 
            return key
    

with open("poi_data/taiwan_districts_mapping.json", 'r', encoding='utf-8-sig') as file:
    discrits = json.load(file)
    dataset = {}
    for county in discrits:
        dataset[county] = {}
        for town in discrits[county]:
            dataset[county][town] = []

with open("poi_data/scenic_spot_C_f.json", 'r', encoding='utf-8-sig') as file:
    scenic_spot = json.load(file)
    err = 0
    ok = 0
    noaddr = 0
    for poi in scenic_spot['XML_Head']['Infos']['Info']:
        if poi['Add'] == '' or len(poi['Add']) < 6:
            noaddr += 1
            continue
        addr = re.sub(r'台', '臺', poi['Add'])
        countyflag, county = countyMapping(discrits, addr)
        try:
            town = townMapping(discrits[county], addr, countyflag)
            dataset[county][town].append({"Name":poi['Name'], "Add":poi['Add']})
        except:
            err += 1
            print (county, town)
            print ({"Name":poi['Name'], "Add":poi['Add']})
        else:
            ok += 1
             
with open("poi_data/location_POIs.json", 'w', encoding='utf8') as file:
    json.dump(dataset, file, ensure_ascii=False)
# Out:
# None 南竿鄉
# {'Name': '印地安人頭岩', 'Add': '在大漢據點正上方，可於面對北海坑道右側觀景台欣賞'}
# None 金山區
# {'Name': '金包里古道', 'Add': '陽金公路大油坑至八煙之間'}
# 宜蘭縣 None
# {'Name': '壯圍沙丘旅遊服務園區', 'Add': '宜蘭縣壯濱路二段196巷18號'}
# 新竹縣 None
# {'Name': '情人谷步道', 'Add': '新竹縣內灣大橋後的阿三哥餐廳，由其旁邊的道路往上步行約五分鐘即可到起點'}
# 新竹縣 None
# {'Name': '木馬古道', 'Add': '新竹縣內灣木馬古道'}
# 新竹縣 None
# {'Name': '峰城炭窯 (木炭的家)', 'Add': '新竹縣三峰國小附近'}
# 新竹縣 None
# {'Name': '南大隘休閒景觀道路', 'Add': '新竹縣122縣道南清公路35.5公里往上至白蘭下山122號線道路50公里處終點'}
# 新竹縣 None
# {'Name': '桃山隧道', 'Add': '桃山隧道(新竹縣122縣道南清公路)'}
# 新竹縣 None
# {'Name': '文化兒童公園', 'Add': '新竹縣文平路與吳濁流路交叉口'}
# 新竹縣 None
# {'Name': '鳳山溪麻園生態公園', 'Add': '新竹縣台一號道(中華路)過鳳山溪橋進入長青路沿鳳山溪堤防，鳳山溪堤防內'}
# 苗栗縣 None
# {'Name': '玉清宮', 'Add': '苗栗市玉清里坡塘下1號'}
# 苗栗縣 None
# {'Name': '老家藝文空間', 'Add': '苗栗市中苗里建台街1巷13號'}
# None 仁愛鄉
# {'Name': '永興大樟樹', 'Add': '永興村永興活動中心旁，鄰投58號鄉道'}
# 嘉義市 None
# {'Name': '林業試驗所中埔研究中心', 'Add': '行政中心:嘉義市文化路432巷65號'}
# None 阿里山鄉
# {'Name': '沼平公園', 'Add': '阿里山森林遊樂區內'}
# None 新港鄉
# {'Name': '新港三朵花的動人故事', 'Add': '板頭村北港溪畔河堤上'}
# None 阿里山鄉
# {'Name': '象鼻木', 'Add': '阿里山森林遊樂區內'}
# None 阿里山鄉
# {'Name': '高山博物館', 'Add': '位於阿里山森林遊樂區內'}
# None 阿里山鄉
# {'Name': '受鎮宮', 'Add': '位於阿里山森林遊樂區內'}
# None 六腳鄉
# {'Name': '朴子溪自行車道', 'Add': '東起蒜頭糖廠蔗埕文化園區，西至東石漁人碼頭'}
# None 竹崎鄉
# {'Name': '奮起湖神社遺址', 'Add': '神社遺址位於奮起湖北方森林木棧道上的一景'}
# None 番路鄉
# {'Name': '隙頂休閒步道區', 'Add': '位於阿里山半山腰，阿里山公路39~41公里'}
# None 阿里山鄉
# {'Name': '隙頂之星步道', 'Add': '阿里山公路五十四公里附近'}
# None 水上鄉
# {'Name': '朴子溪生態', 'Add': '朴子溪東石大橋段'}
# 嘉義市 None
# {'Name': '穿梭神木之間', 'Add': '嘉義長庚醫院西側小槺榔一路與二路間之兒童公園'}
# 屏東縣 None
# {'Name': '崇蘭蕭家古厝', 'Add': '屏東市900崇蘭里69號(洛陽街附近)'}
# 屏東縣 None
# {'Name': '東山禪寺', 'Add': '屏東市修德巷6號'}
# 屏東縣 None
# {'Name': '聖十字架教堂', 'Add': '屏東市公園路23號'}
# 新竹市 None
# {'Name': '新竹州廳(新竹市政府)', 'Add': '新竹市中正路120號'}
# 新竹市 None
# {'Name': '新竹驛(新竹火車站)', 'Add': '新竹市中華路二段445號'}
# 新竹市 None
# {'Name': '新竹火車站－站前廣場', 'Add': '新竹市中華路二段445號'}
# 新竹市 None
# {'Name': '新竹孔廟', 'Add': '新竹市公園路、東山路口'}
# 新竹市 None
# {'Name': '新竹護城河親水公園', 'Add': '新竹市區林森路經東門城至世界街口'}
# 新竹市 None
# {'Name': '竹蓮寺', 'Add': '新竹市竹蓮街100號'}
# 新竹市 None
# {'Name': '金山寺﹝開臺金山寺﹞', 'Add': '新竹市仙山里金山路115號'}
# 新竹市 None
# {'Name': '國立清華大學', 'Add': '新竹市光復路二段101號'}
# 新竹市 None
# {'Name': '國立交通大學', 'Add': '新竹市大學路1001號(光復校區)'}
# 新竹市 None
# {'Name': '國立新竹教育大學', 'Add': '新竹市南大路521號'}
# 新竹市 None
# {'Name': '中華大學', 'Add': '新竹市五福路二段707號'}
# 新竹市 None
# {'Name': '玄奘大學', 'Add': '新竹市玄奘路48號'}
# 新竹市 None
# {'Name': '元培科技大學', 'Add': '新竹市元培路306號'}
# 新竹市 None
# {'Name': '新竹港南濱海風景區', 'Add': '新竹市海埔路600號'}
# 新竹市 None
# {'Name': '麗池九曲橋', 'Add': '新竹市光復路與公園路'}
# 新竹市 None
# {'Name': '玻璃工藝博物館', 'Add': '新竹市東大路一段2號'}
# 新竹市 None
# {'Name': '影像博物館', 'Add': '新竹市中正路65號'}
# 新竹市 None
# {'Name': '古奇峰文物館', 'Add': '新竹市高峰路306巷66號'}
# 新竹市 None
# {'Name': '消防博物館', 'Add': '新竹市中山路4號'}
# 新竹市 None
# {'Name': '新竹信用組合', 'Add': '新竹市大同路130號'}
# 新竹市 None
# {'Name': '張氏節孝坊', 'Add': '新竹市國華街87號旁'}
# 新竹市 None
# {'Name': '蘇氏節孝坊', 'Add': '新竹市湳雅街147巷45弄'}
# 新竹市 None
# {'Name': '新竹關帝廟', 'Add': '新竹市關帝里南門街109-1號'}
# 新竹市 None
# {'Name': '楊氏節孝坊', 'Add': '新竹市石坊街4號旁'}
# 新竹市 None
# {'Name': '新竹專賣局', 'Add': '新竹市東門街59號'}
# 新竹市 None
# {'Name': '辛志平校長故居', 'Add': '新竹市東門街32號'}
# 新竹市 None
# {'Name': '國立新竹高中劍道館', 'Add': '新竹市學府路36號'}
# 新竹市 None
# {'Name': '鄭用錫墓', 'Add': '新竹市明湖路243巷軍人公墓內'}
# 新竹市 None
# {'Name': '李錫金孝子坊', 'Add': '新竹市明湖路486巷旁'}
# 新竹市 None
# {'Name': '新竹神社殘跡(大陸人民處理中心)', 'Add': '新竹市崧嶺路122號'}
# 新竹市 None
# {'Name': '新竹市立動物園', 'Add': '新竹市公園路279號'}
# 新竹市 None
# {'Name': '看海公園', 'Add': '新竹市沿海十七公里海岸'}
# 新竹市 None
# {'Name': '海天一線看海區', 'Add': '新竹市沿海十七公里海岸'}
# 新竹市 None
# {'Name': '紅樹林公園', 'Add': '新竹市沿海十七公里海岸'}
# 新竹市 None
# {'Name': '風情海岸', 'Add': '新竹市沿海十七公里海岸'}
# 新竹市 None
# {'Name': '海山漁港觀海台', 'Add': '新竹市沿海十七公里海岸'}
# 新竹市 None
# {'Name': '南港賞鳥區', 'Add': '新竹市沿海十七公里海岸'}
# 新竹市 None
# {'Name': '變葉木步道', 'Add': '新竹市東南郊 (十八尖山公園)'}
# 新竹市 None
# {'Name': '桂花巷', 'Add': '新竹市東南郊 (十八尖山公園)'}
# 新竹市 None
# {'Name': '幸福亭', 'Add': '新竹市東南郊 (十八尖山公園)'}
# 新竹市 None
# {'Name': '觀音亭', 'Add': '新竹市東南郊 (十八尖山公園)'}
# 新竹市 None
# {'Name': '國父百年紀念亭', 'Add': '新竹市東南郊 (十八尖山公園)'}
# 新竹市 None
# {'Name': '早起會廣場', 'Add': '新竹市東南郊 (十八尖山公園)'}
# 新竹市 None
# {'Name': '動力基準站', 'Add': '新竹市東南郊 (十八尖山公園)'}
# 新竹市 None
# {'Name': '無上和尚紀念公園', 'Add': '靠近 新竹市 青草湖明湖路1135號 (靈隱寺)'}
# 新竹市 None
# {'Name': '天公壇公園吊橋', 'Add': '靠近 新竹市中山路431巷36號(天公壇)'}
# 新竹市 None
# {'Name': '飛機模型陳列館', 'Add': '新竹市東大路三段110巷15號'}
# 新竹市 None
# {'Name': '眷村博物館', 'Add': '新竹市東大路二段105號'}
# 新竹市 None
# {'Name': '北門大街', 'Add': '新竹市北大路與中山路之間'}
# 嘉義市 None
# {'Name': '獄政博物館(嘉義舊監獄)', 'Add': '嘉義市維新路140號'}
# 嘉義市 None
# {'Name': '蘭潭月影潭心', 'Add': '嘉義市鹿寮里紅毛埤187號之4'}
# 嘉義市 None
# {'Name': '射日塔', 'Add': '嘉義市公園街46號【嘉義公園內】'}
# 嘉義市 None
# {'Name': '嘉義鐵道藝術村', 'Add': '嘉義市北興街37-10號'}
# 嘉義市 None
# {'Name': '行嘉吊橋', 'Add': '嘉義市吳鳳南路547巷附近'}
# 嘉義市 None
# {'Name': '港坪運動公園', 'Add': '嘉義市大同路100號'}
# 嘉義市 None
# {'Name': '圓林仔社區', 'Add': '嘉義市東義路566巷'}
# 嘉義市 None
# {'Name': '軍輝橋', 'Add': '嘉義市省道台18線，跨越八掌溪'}
# 嘉義市 None
# {'Name': '蘭潭風景區', 'Add': '嘉義市鹿寮里紅毛埤187號之4'}
# 嘉義市 None
# {'Name': '蘭潭後山公園', 'Add': '位於嘉義市東郊山仔頂附近，距市區3公里'}
# 嘉義市 None
# {'Name': '百年嘉義公園', 'Add': '嘉義市啟明路264號'}
# 嘉義市 None
# {'Name': '嘉義樹木園', 'Add': '嘉義市王田里山子頂270號'}
# 嘉義市 None
# {'Name': '嘉大植物園', 'Add': '嘉義市鹿寮里學府路300號'}
# None 東區
# {'Name': '中正公園', 'Add': '位於國華街、民權路、忠義街和北榮街所構築的中央位置'}
# 嘉義市 None
# {'Name': '中央噴水池', 'Add': '嘉義市中山路中段的圓環'}
# 嘉義市 None
# {'Name': '嘉油鐵馬道', 'Add': '嘉義市世賢路四段中油廠區旁設為起點，北回歸線站天文廣場為終點'}
# 嘉義市 None
# {'Name': '世賢路自行車道', 'Add': '嘉義市世賢路(自保安四路至新民路)'}
# 嘉義市 None
# {'Name': '蕭萬長文物館', 'Add': '嘉義市鹿寮里學府路300號(嘉義大學蘭潭校區)'}
# 嘉義市 None
# {'Name': '王祖母許太夫人墓', 'Add': '嘉義市盧厝里羌母寮41號'}
# 嘉義市 None
# {'Name': '頂庄社區', 'Add': '嘉義市頂庄里義教街538號'}
# None 坪林區
# {'Name': '坪林親水吊橋', 'Add': '坪林旅遊服務中心斜對面'}
# None 小港區
# {'Name': '九番埤濕地公園', 'Add': '東起自中山高速公路，西側與九番埤相連'}
# None 甲仙區
# {'Name': '六義山登山步道', 'Add': '南段紫霞入口-  南橫公路【台20:53.4K】處 南段百葉入口-  南橫公路【台20:55.1K】處'}
# None 大樹區
# {'Name': '十八羅漢山風景區', 'Add': '省道台27甲線，位於新威到六龜公路的6個隧道中間。'}
# None 那瑪夏區
# {'Name': '援中港生態濕地公園', 'Add': '後勁溪與典寶溪之間，德中路與援中路交叉口'}
# None 前鎮區
# {'Name': '寶來花賞溫泉公園', 'Add': '寶來國中後方，比鄰浦來溪頭社戰道'}
# 高雄市 None
# {'Name': '國立科學工藝博物館', 'Add': '高雄市九如一路720號'}
# 嘉義市 None
# {'Name': '嘉義文化創意產業園區 (文創發展司)', 'Add': '嘉義市中山路616號'}
# 新竹市 None
# {'Name': '蘇格貓底二手書咖啡店', 'Add': '新竹市  新竹市光復路2段101號'}
# 嘉義市 None
# {'Name': '洪雅書房', 'Add': '嘉義市  嘉義市長榮街116號（近忠孝路、嘉基護理之家後方第二間）'}

# %%
print ("Can't find location: {}".format(err))
print ("No address or short address: {}".format(noaddr))
print ("Can find location: {}".format(ok))
# Out:
# Can't find location: 107
# No address or short address: 85
# Can find location: 4966
